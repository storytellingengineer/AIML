# %%
import pandas as pd

# %%
data = pd.read_csv("mushrooms.csv")

# %%
data.head()
# Out:
#   class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0     p         x           s         n       t    p               f
# 1     e         x           s         y       t    a               f
# 2     e         b           s         w       t    l               f
# 3     p         x           y         w       t    p               f
# 4     e         x           s         g       f    n               f
#
#   gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# 0            c         n          k  ...                        s
# 1            c         b          k  ...                        s
# 2            c         b          n  ...                        s
# 3            c         n          n  ...                        s
# 4            w         b          k  ...                        s
#
#   stalk-color-above-ring stalk-color-below-ring veil-type veil-color  \
# 0                      w                      w         p          w
# ...

# %%
data['class'].unique()
# Out:
# array(['p', 'e'], dtype=object)

# %%
data[data['class'] == 'p'].shape
# Out:
# (3916, 23)

# %%
data['cap-shape'].unique()
# Out:
# array(['x', 'b', 's', 'f', 'k', 'c'], dtype=object)

# %%
feature_data = data['cap-shape']

# %%
feature_data.value_counts()
# Out:
# x    3656
# f    3152
# k     828
# b     452
# s      32
# c       4
# Name: cap-shape, dtype: int64

# %%
feature_values_relative_frequencies = feature_data.value_counts()/data.shape[0]

# %%
feature_values_relative_frequencies
# Out:
# x    0.450025
# f    0.387986
# k    0.101920
# b    0.055638
# s    0.003939
# c    0.000492
# Name: cap-shape, dtype: float64

# %%
training_data_len = int(0.75*len(data))

training_data = data.iloc[0:training_data_len,]

# %%
testing_data = data.iloc[training_data_len:,]

# %%
training_data
# Out:
#      class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0        p         x           s         n       t    p               f
# 1        e         x           s         y       t    a               f
# 2        e         b           s         w       t    l               f
# 3        p         x           y         w       t    p               f
# 4        e         x           s         g       f    n               f
# ...    ...       ...         ...       ...     ...  ...             ...
# 6088     p         f           s         n       f    y               f
# 6089     p         f           s         n       f    s               f
# 6090     p         f           s         e       f    f               f
# 6091     p         f           y         n       f    y               f
# 6092     p         f           s         n       f    f               f
#
#      gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# ...

# %%
training_data['cap-shape'].unique()
# Out:
# array(['x', 'b', 's', 'f', 'k', 'c'], dtype=object)

# %%
testing_data
# Out:
#      class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 6093     p         f           y         n       f    f               f
# 6094     p         f           s         e       f    y               f
# 6095     p         f           s         e       f    f               f
# 6096     p         x           y         e       f    f               f
# 6097     p         f           s         n       f    y               f
# ...    ...       ...         ...       ...     ...  ...             ...
# 8119     e         k           s         n       f    n               a
# 8120     e         x           s         n       f    n               a
# 8121     e         f           s         n       f    n               a
# 8122     p         k           y         n       f    y               f
# 8123     e         x           s         n       f    n               a
#
#      gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# ...

# %%
class_p = training_data[training_data['class'] == 'p']
class_p
# Out:
#      class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0        p         x           s         n       t    p               f
# 3        p         x           y         w       t    p               f
# 8        p         x           y         w       t    p               f
# 13       p         x           y         w       t    p               f
# 17       p         x           s         n       t    p               f
# ...    ...       ...         ...       ...     ...  ...             ...
# 6088     p         f           s         n       f    y               f
# 6089     p         f           s         n       f    s               f
# 6090     p         f           s         e       f    f               f
# 6091     p         f           y         n       f    y               f
# 6092     p         f           s         n       f    f               f
#
#      gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# ...

# %% [markdown]
# \begin{equation}
# P(Cap-shape \cap Cap-surface | Class = p)\\[10pt]
# P(Cap-shape \cap Cap-surface | Class = e)\\[10pt]
# P(Cap-shape \cap Cap-surface \cap ......\cap habitat | Class = p)\\[10pt]
# \end{equation}

# %%
numerator1 = class_p[(class_p['cap-shape'] == 'x') & (class_p['cap-surface'] == 's')]
denominator1 = class_p

# %%
data['cap-surface'].unique()
# Out:
# array(['s', 'y', 'f', 'g'], dtype=object)

# %%
#Laplace Smoothing
P1 = (numerator1.shape[0]+2)/(denominator1.shape[0]+10)

# %%
P1
# Out:
# 0.13388429752066117

# %%
class_e = training_data[training_data['class'] == 'e']
class_e.columns
# Out:
# Index(['class', 'cap-shape', 'cap-surface', 'cap-color', 'bruises', 'odor',
#        'gill-attachment', 'gill-spacing', 'gill-size', 'gill-color',
#        'stalk-shape', 'stalk-root', 'stalk-surface-above-ring',
#        'stalk-surface-below-ring', 'stalk-color-above-ring',
#        'stalk-color-below-ring', 'veil-type', 'veil-color', 'ring-number',
#        'ring-type', 'spore-print-color', 'population', 'habitat'],
#       dtype='object')

# %%
numerator2 = class_e[(class_e['cap-shape']=='x') & (class_e['cap-surface']=='s')]
denominator2 = class_e

# %%
P2 = (numerator2.shape[0]+2)/(denominator2.shape[0]+10)
P2
# Out:
# 0.10262659084754942

# %%
data['cap-shape'].unique()
# Out:
# array(['x', 'b', 's', 'f', 'k', 'c'], dtype=object)

# %%
numerator3 = class_p[(class_p['cap-shape'] == 'x') & (class_p['cap-surface'] == 's') & (class_p['cap-color']=='y') & (class_p['bruises']=='t') & (class_p['odor']=='a') & (class_p['gill-attachment']=='f') & (class_p['gill-spacing']=='c') & (class_p['gill-size']=='b') & (class_p['gill-color']=='k') & (class_p['stalk-shape']=='e') & (class_p['stalk-root']=='c') & (class_p['stalk-surface-above-ring']=='s') & (class_p['stalk-surface-below-ring']=='s') & (class_p['veil-type']=='p') & (class_p['veil-color']=='w') & (class_p['ring-number']==
'o') & (class_p['ring-type']=='p') & (class_p['spore-print-color']=='n') & (class_p['population']=='n') & (class_p['habitat']=='g')] 
denominator3 = class_p

# %%
#Laplace Smoothing
P3 = (numerator3.shape[0]+23)/(denominator3.shape[0]+116)
P3
# Out:
# 0.009105304829770388
