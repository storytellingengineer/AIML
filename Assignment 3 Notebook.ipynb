# %% [markdown]
# # Download the dataset from the following link below:
#
# https://drive.google.com/file/d/1iz2oI548OwdA1GkrHOm99Ew0qPqpIxYx/view?usp=sharing
#
# # When you read the dataset,it will just look like as shown below:

# %%
import pandas as pd

# %%
df = pd.read_csv("train.csv")

# %%
df.shape
# Out:
# (200000, 202)

# %%
df.head()
# Out:
#    ID_code  target    var_0   var_1    var_2   var_3    var_4   var_5   var_6  \
# 0  train_0       0   8.9255 -6.7863  11.9081  5.0930  11.4607 -9.2834  5.1187
# 1  train_1       0  11.5006 -4.1473  13.8588  5.3890  12.3622  7.0433  5.6208
# 2  train_2       0   8.6093 -2.7457  12.0805  7.8928  10.5825 -9.0837  6.9427
# 3  train_3       0  11.0604 -2.1518   8.9522  7.1957  12.5846 -1.8361  5.8428
# 4  train_4       0   9.8369 -1.4834  12.8746  6.6375  12.2772  2.4486  5.9405
#
#      var_7  ...  var_190  var_191  var_192  var_193  var_194  var_195  \
# 0  18.6266  ...   4.4354   3.9642   3.1364   1.6910  18.5227  -2.3978
# 1  16.5338  ...   7.6421   7.7214   2.5837  10.9516  15.4305   2.0339
# 2  14.6155  ...   2.9057   9.7905   1.6704   1.6858  21.6042   3.1417
# 3  14.9250  ...   4.4666   4.7433   0.7178   1.4214  23.0347  -1.2706
# 4  19.2514  ...  -1.4905   9.5214  -0.1508   9.1942  13.2876  -1.5121
#
#    var_196  var_197  var_198  var_199
# ...

# %% [markdown]
# # Compute the following probabilities:
#
# \begin{equation}
# P(target = 0 | (1 \leq var_0 \leq 15) \cap (-10 \leq var_1 \leq 9.5) \cap (4 \leq var_2 \leq 18))
# \end{equation}
#
# \begin{equation}
# P((1 \leq var_0 \leq 15) \cap (-10 \leq var_1 \leq 9.5) \cap (4 \leq var_2 \leq 18) | target = 0)
# \end{equation}
#
# \begin{equation}
# P(target = 1 | (1 \leq var_0 \leq 15) \cap (-10 \leq var_1 \leq 9.5) \cap (4 \leq var_2 \leq 18))
# \end{equation}
#
# \begin{equation}
# P((1 \leq var_0 \leq 15) \cap (-10 \leq var_1 \leq 9.5) \cap (4 \leq var_2 \leq 18) | target = 1)
# \end{equation}

# %%
target_unique_values = df['target'].unique()

# %%
target_unique_values
# Out:
# array([0, 1], dtype=int64)

# %%
target_0 = df[df['target'] == 0]
target_1 = df[df['target'] == 1]

# %%
numerator1 = target_0[(target_0['var_0']<=15) & (target_0['var_0']>=1) & (target_0['var_1']<=9.5) & (target_0['var_1']>=-10) & (target_0['var_2']>=4) & (target_0['var_2']<=18)]
numerator4 = target_1[(target_1['var_0']<=15) & (target_1['var_0']>=1) & (target_1['var_1']<=9.5) & (target_1['var_1']>=-10) & (target_1['var_2']>=4) & (target_1['var_2']<=18)]

# %%
P2 = numerator1.shape[0]/target_0.shape[0]

# %%
P2
# Out:
# 0.9110015452857667

# %%
numerator2 = df[(df['var_0']>=1) & (df['var_0']<=15) & (df['var_1']>=-10) & (df['var_1']<=9.5) & (df['var_2']>=4) & (df['var_2']<=18)]

# %%
numerator2
# Out:
#              ID_code  target    var_0   var_1    var_2   var_3    var_4  \
# 0            train_0       0   8.9255 -6.7863  11.9081  5.0930  11.4607
# 1            train_1       0  11.5006 -4.1473  13.8588  5.3890  12.3622
# 2            train_2       0   8.6093 -2.7457  12.0805  7.8928  10.5825
# 3            train_3       0  11.0604 -2.1518   8.9522  7.1957  12.5846
# 4            train_4       0   9.8369 -1.4834  12.8746  6.6375  12.2772
# ...              ...     ...      ...     ...      ...     ...      ...
# 199995  train_199995       0  11.4880 -0.4956   8.2622  3.5142  10.3404
# 199996  train_199996       0   4.9149 -2.4484  16.7052  6.6345   8.3096
# 199997  train_199997       0  11.2232 -5.0518  10.5127  5.6456   9.3410
# 199998  train_199998       0   9.7148 -8.6098  13.6104  5.7930  12.5173
# 199999  train_199999       0  10.8762 -5.7105  12.1183  8.0328  11.5577
#
#           var_5   var_6    var_7  ...  var_190  var_191  var_192  var_193  \
# ...

# %%
numerator2['target'].unique()
# Out:
# array([0, 1], dtype=int64)

# %%
P_var_target1 = numerator2[numerator2['target']==0]
P_var_target2 = numerator4[numerator4['target']==1]

# %%
P_var_target2
# Out:
#              ID_code  target    var_0   var_1    var_2    var_3    var_4  \
# 29          train_29       1   5.3301 -2.6064  13.1913   3.1193   6.6483
# 63          train_63       1   7.7072  0.0183   9.9974   8.3524   9.2886
# 65          train_65       1  10.5358 -2.5439   8.7394   6.7548  14.4099
# 71          train_71       1   6.7547  2.5973  14.2141   8.3514   7.4942
# 72          train_72       1   8.6470  0.4462  10.9808  10.1859  13.9121
# ...              ...     ...      ...     ...      ...      ...      ...
# 199966  train_199966       1  13.5797  2.5526   6.0512   5.2730  12.2182
# 199976  train_199976       1   7.9663 -2.8485   9.0919   7.3298   9.6690
# 199981  train_199981       1  12.8140  0.6386  14.1657   7.1044   8.9365
# 199986  train_199986       1  12.0298 -8.7800   7.7071   7.4015   9.2305
# 199990  train_199990       1  14.1475  1.8568  11.0066   3.6779  12.1944
#
#           var_5   var_6    var_7  ...  var_190  var_191  var_192  var_193  \
# ...

# %%
P1 = (P_var_target1.shape[0])/(numerator2.shape[0])

# %%
P1
# Out:
# 0.9046704312738393

# %%
P4 = numerator4.shape[0]/target_1.shape[0]

# %%
P4
# Out:
# 0.8592894815404518

# %%
P3 = (P_var_target2.shape[0])/(numerator2.shape[0])

# %%
P3
# Out:
# 0.0953295687261607
